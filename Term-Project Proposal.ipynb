# %% [markdown]
# # Term - Project: Proposal Submission
# #### 2020103310 글로벌문화기술학과 전수림

# %% [markdown]
# **1. 주제:** 키오스크 프로그래밍 하기

# %% [markdown]
# **2. 주제 선정 이유:**
# - 오늘날 카드 결제는 키오스크를 사용하는 경우가 많아지고 있다. 그러나 현금과 카드 결제가 모두 가능한 키오스크는 흔하지 않다. 그리하여 직접 현금과 카드 결제가 모두 가능한 키오스크를 프로그래밍 해보고자 한다.
#
#
# - 최근에 자판기에 대한 flow chart를 그려 보았다. 키오스크와 자판기의 코딩 흐름이 비슷할 것 같다는 생각이 들었다. 이번 계기로 전에 그렸던 flow chart를 비슷하게 구현해보고 싶다. (* 별첨: 직접 그린 자판기 flow chart)
#
#
# - 지금까지 배운 Python을 최대한 활용하여 실력도 향상할 수 있는 주제가 키오스크라고 생각하였다.

# %% [markdown]
# **3. 도출해내야 하는 결과:**
# - 상품 및 거스름돈 재고 확인 및 구매 가능 여부 알리기
#
#
# - 고객이 선택한 결제 수단에 맞추어 제대로 작동할 것
#
#
# - 현금 계산의 경우, 고객이 선택한 상품들과 현재 투입된 금액 비교 및 거스름돈을 정확히 계산하고 출력시키기
#
#
# - (현금)영수증과 주문번호 제대로 출력시키기
#
#
# - 상황에 따라 스크린에 나와야 하는 문구 (ex.결제 오류, 투입 금액 부족, 재고 없음 등)
#
#
# - etc

# %% [markdown]
# **4. 프로젝트 진행 방향:**
# - 프로젝트 시작 전, 직접 사용해보거나 검색을 통해 키오스크의 사용방법 및 작동원리를 확실히 이해하기
#
#
# - 이전에 그린 자판기 flow chart를 수정 및 추가하여 현재 구현하고 싶은 키오스크 flow chart를 디테일하게 그리기
#
#
# - flow chart를 보고 그대로 프로그래밍 하기 시작 (conditional statement, loop, 앞으로 배울 내용 등을 활용할 것)
#
#
# - 완성된 코드가 flow chart 또는 시중에 있는 키오스크와 같거나 비슷한지 비교, 확인, 수정하기 (수정사항이 있다면 다시 되돌아가기)

# %% [markdown]
# **5. 구체적인 진행 계획:**
# 1) 4/26 Proposal ~ 5/17 Mid-Term Report Submission:
# - flow chart 그리기 및 수정을 반복하여 완벽한 완성본 만들기
#
#
# - flow chart 보고 앞부분 프로그래밍하기
#
#
# - 중간 보고서 작성하기
#
#
# 2)  5/17 Mid-Term Report Submission ~ 6/7 Final Report Submission:
# - 코드 끝까지 완성시키기
#
#
# - 정확히 작동하는지 점검 반복
#
#
# - 오류 발생 시, 앞으로 되돌아가 수정할 것
#
#
# - 최종 보고서 작성하기

# %% [markdown]
# **6. 프로젝트를 위해 사용 및 참고할 것:**
# - flow chart를 그릴 도구: https://app.diagrams.net/
#
#
# - 혼자 공부하는 파이썬_ 윤인성: https://book.naver.com/bookdb/book_detail.nhn?bid=15028688
#
#
# - Think Python 및 강의노트
#
#
# - 위키백과, 나무위키, 구글, 네이버, 논문, 키오스크 회사 등을 통해  키오스크 작동 원리 검색

# %% [markdown]
# **7. * 별첨 자판기 flow chart**
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
